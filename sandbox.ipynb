# %%
import numpy
from src.usdai_agent.usda_client import USDAClient

# %reload_ext autoreload
# %autoreload 2

# %%
client = USDAClient(api_key="46C7AE24-554C-34B7-811F-40AA2AC432AA")

# %%
client.fetch()
# Out:
#   county_code begin_code watershed_code  ...  year commodity_desc state_alpha
# 0                     00       00000000  ...  2023           CORN          IA
# 1                     00       00000000  ...  2023           CORN          IA
# 2                     00       00000000  ...  2023           CORN          IA
# 3                     00       00000000  ...  2023           CORN          IA
# 4                     00       00000000  ...  2023           CORN          IA
#
# [5 rows x 39 columns]

# %%
client.check_connection()
# Out:
# True
